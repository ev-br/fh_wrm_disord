# %%
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
# !ls
# Out:
# a.out		  event_mod.f	       mumbers.mod	 rndm_mumbers.f
# arch		  fermi-hubbard.f      nmnm_tst_2_1.dat  rndm_tst_2_1.dat
# cnf_tst_2_1.dat   fermi-hubbard-mpi.f  out_tst_2_1	 stat_tst_2_1.dat
# ct3d_tst_2_1.dat  gim.dat	       par_tst		 tree.mod
# data		  infile	       par_tst_2	 Untitled.ipynb
# det_n2.f	  Makefile	       README		 vrbls.mod
# det_n2.mod	  merge.f	       repro_runs	 Vsmall.dat
# det_tst_2_1.dat   mrg21.f	       res_tst.txt

# %%
vsmall = np.loadtxt("Vsmall.dat")
nmnm = np.loadtxt("nmnm_tst_2_1.dat")

# %%
plt.plot(vsmall[:100, 0], vsmall[:100, 1], 'o')
plt.plot(nmnm[:100, 0], nmnm[:100, 1], 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
vsmall[:, 1]
# Out:
# array([0.00000000e+00, 0.00000000e+00, 2.41545894e-07, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %% [markdown]
# ## m5.2 test

# %%
ed = np.loadtxt("./tests/m5.2/nmnm_m5.2L4b3.5_1.dat")
per = np.loadtxt("./repro_runs/m5.2L4/nmnm_m5.2L4b3.5_1.dat")

plt.plot(per[:200, 0], per[:200, 1], 'o')
plt.plot(ed[:200, 0], ed[:200, 1], 'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# !ls repro_runs/m5.2L4
# Out:
# an_m5.2L4b3.5	       det_m5.2L4b4.0_1.dat   par_m5.2L4b3.5
# an_m5.2L4b4.0	       det_m5.2L4b4.5_1.dat   par_m5.2L4b4.0
# an_m5.2L4b4.5	       det_m5.2L4b5.0_1.dat   par_m5.2L4b4.5
# an_m5.2L4b5.0	       infile		      par_m5.2L4b5.0
# cnf_m5.2L4b3.5_1.dat   nm35.png		      rndm_m5.2L4b3.5_1.dat
# cnf_m5.2L4b4.0_1.dat   nmnm_m5.2L4b3.5_1.dat  rndm_m5.2L4b4.0_1.dat
# cnf_m5.2L4b4.5_1.dat   nmnm_m5.2L4b4.0_1.dat  rndm_m5.2L4b4.5_1.dat
# cnf_m5.2L4b5.0_1.dat   nmnm_m5.2L4b4.5_1.dat  rndm_m5.2L4b5.0_1.dat
# ct3d_m5.2L4b3.5_1.dat  nmnm_m5.2L4b5.0_1.dat  run_m5.2L4.sbatch
# ct3d_m5.2L4b4.0_1.dat  out_m5.2L4b3.5_1       stat_m5.2L4b3.5_1.dat
# ct3d_m5.2L4b4.5_1.dat  out_m5.2L4b4.0_1       stat_m5.2L4b4.0_1.dat
# ct3d_m5.2L4b5.0_1.dat  out_m5.2L4b4.5_1       stat_m5.2L4b4.5_1.dat
# det_m5.2L4b3.5_1.dat   out_m5.2L4b5.0_1       stat_m5.2L4b5.0_1.dat
